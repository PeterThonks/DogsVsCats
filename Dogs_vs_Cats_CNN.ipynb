# %% [markdown]
# Implementación del paper "Image Classification for Dogs and Cats" empleando data augmentation de "The Effectiveness of Data Augmentation in Image Classification using Deep Learning"

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, Dropout, ReLU, MaxPool2D, AvgPool2D, Input, LeakyReLU, concatenate, ZeroPadding2D
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tqdm import tqdm
from random import choice
from tensorflow.keras.models import Model
from keras.layers import add
# %matplotlib inline
tf.random.set_seed(0)
import os
from sklearn.model_selection import train_test_split
import random
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#%cd '/content/drive/MyDrive/Pucp/Ciclo 22-1/TAC/TA/Code'
# Out:
# /content/drive/MyDrive/Pucp/Ciclo 22-1/TAC/TA/Code

# %%
# %cd '/content/drive/MyDrive/TAC/TA/Code'
# Out:
# /content/drive/.shortcut-targets-by-id/1l_7B3CRTOTHS4NP0iTHC2KegESAGxlXK/TA/Code

# %%
# Definición de variables globales
IMAGE_WIDTH=350
IMAGE_HEIGHT=350
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
IMAGE_COUNT=3500
AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# # Leer imagenes

# %%
# Rutas de archivos
path_train = "train1"
path_test = "test1"
batch_size = 15
class_names = ["dog", "cat"]

# %%
# Almacenando nombres train de archivos en df
filenames = os.listdir(path_train)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})
df.head()
# Out:
#        filename  category
# 0  dog.9136.jpg         1
# 1  dog.9101.jpg         1
# 2  dog.9133.jpg         1
# 3  dog.9128.jpg         1
# 4    dog.91.jpg         1

# %%
# Visualizando cantidad por categoria
df['category'].value_counts().plot.bar()

# %%
# Vizualisando imagen aleatoria del df
sample = random.choice(filenames)
image = load_img("train1/"+sample)
plt.imshow(image)

# %%
# Separando data de train y validate
train_df, validate_df = train_test_split(df, test_size=0.2)
train_df = train_df.reset_index()
validate_df = validate_df.reset_index()

# De acuerdo con el paper, solo se toma 2000 imagenes para train y 500 para validate
train_df = train_df.sample(n=2000).reset_index()
validate_df = validate_df.sample(n=500).reset_index()

# Cast de columna
train_df['category'] = train_df['category'].astype(str)
validate_df['category'] = validate_df['category'].astype(str)

# Cantidad total por train y validate
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
# Data augmentation de acuerdo al paper
train_datagen = ImageDataGenerator(
        rescale=1./255,
        zoom_range=0.4,
        rotation_range=50,
        width_shift_range=0.3,
        height_shift_range=0.3,
        shear_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# Lectura de imagenes train de acuerdo a la cantidad señalada
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    path_train, 
    x_col='filename',
    y_col='category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 2000 validated image filenames belonging to 2 classes.

# %%
# Lectura de imagenes validate de acuerdo a la cantidad señalada
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    path_train, 
    x_col='filename',
    y_col='category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 500 validated image filenames belonging to 2 classes.

# %%
def plot_random_image(path, list_of_images_paths):
  #Seleccionar aleatoriamente una imagen
  random_image_path = choice(list_of_images_paths)

  #Cargar la imagen
  image = Image.open(path + "/" + random_image_path).convert("RGBA")

  #Mostrar la imagen
  plt.imshow(image)
  plt.axis("off")

# %%
# Vizualisando imagen aleatoria del train_generator
plot_random_image(path_train, train_generator.filenames)

# %% [markdown]
# # Crear modelo

# %%
def create_model():
    K.clear_session()
    in_layer = Input(shape=(IMAGE_WIDTH,IMAGE_HEIGHT,IMAGE_CHANNELS))
    zero_p_1 = ZeroPadding2D(padding=(2, 2))(in_layer)
    conv_1 = Conv2D(96, (11, 11), strides=4, activation='relu', padding = "valid")(zero_p_1)
    mp_1 = MaxPool2D((2, 2))(conv_1)

    zero_p_2 = ZeroPadding2D(padding=(2, 2))(mp_1)
    conv_2 = Conv2D(256, (5, 5), activation='relu')(zero_p_2)
    mp_2 = MaxPool2D((2, 2))(conv_2)

    zero_p_3 = ZeroPadding2D(padding=(1, 1))(mp_2)
    conv_3 = Conv2D(384, (3, 3), activation='relu')(zero_p_3)
    
    zero_p_4 = ZeroPadding2D(padding=(1, 1))(conv_3)
    conv_4 = Conv2D(384, (3, 3), activation='relu')(zero_p_4)
    
    zero_p_5 = ZeroPadding2D(padding=(1, 1))(conv_4)
    conv_5 = Conv2D(256, (3, 3), activation='relu')(zero_p_5)

    flatten = Flatten()(conv_5)
    drop_1 = Dropout(0.5)(flatten)
    dense_1 = Dense(4096,activation='relu')(drop_1)
    drop_2 = Dropout(0.3)(dense_1)
    dense_2 = Dense(64,activation='relu')(drop_2)
    out_layer = Dense(1,activation='sigmoid')(dense_2)

    model = Model(inputs=in_layer, outputs=out_layer)
    return model

# %%
lr = 0.0001
model = create_model()
model.compile(optimizer=Adam(learning_rate=lr), loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 350, 350, 3)]     0
#
#  zero_padding2d (ZeroPadding  (None, 354, 354, 3)      0
#  2D)
#
#  conv2d (Conv2D)             (None, 86, 86, 96)        34944
#
#  max_pooling2d (MaxPooling2D  (None, 43, 43, 96)       0
#  )
#
#  zero_padding2d_1 (ZeroPaddi  (None, 47, 47, 96)       0
#  ng2D)
#
#  conv2d_1 (Conv2D)           (None, 43, 43, 256)       614656
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 21, 256)      0
#  2D)
#
#  zero_padding2d_2 (ZeroPaddi  (None, 23, 23, 256)      0
#  ng2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 384)       885120
#
#  zero_padding2d_3 (ZeroPaddi  (None, 23, 23, 384)      0
#  ng2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 384)       1327488
#
#  zero_padding2d_4 (ZeroPaddi  (None, 23, 23, 384)      0
#  ng2D)
#
#  conv2d_4 (Conv2D)           (None, 21, 21, 256)       884992
#
#  flatten (Flatten)           (None, 112896)            0
#
#  dropout (Dropout)           (None, 112896)            0
#
#  dense (Dense)               (None, 4096)              462426112
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_1 (Dense)             (None, 64)                262208
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 466,435,585
# Trainable params: 466,435,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenar modelo

# %%
def show_results(log):
  loss = log.history['loss']
  acc = log.history['accuracy']

  val_loss = log.history['val_loss']
  val_acc = log.history['val_accuracy']
  
  fig, axes = plt.subplots(1, 2, figsize=(14,4))
  ax1, ax2 = axes

  ax1.plot(loss, label='train')
  ax1.plot(val_loss, label='test')
  
  ax1.set_xlabel('epoch'); ax1.set_ylabel('loss')
  
  ax2.plot(acc, label='train')
  ax2.plot(val_acc, label='test')
  
  ax2.set_xlabel('epoch'); ax2.set_ylabel('accuracy')
  
  for ax in axes: ax.legend()

# %%
# Entrando el modelo con 20 epocas
log = model.fit(
    train_generator,
    epochs=20,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size
)
# Out:
# Epoch 1/20
# 133/133 [==============================] - 1830s 14s/step - loss: 0.6979 - accuracy: 0.4987 - val_loss: 0.6928 - val_accuracy: 0.5778
# Epoch 2/20
# 133/133 [==============================] - 66s 496ms/step - loss: 0.6929 - accuracy: 0.5295 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 3/20
# 133/133 [==============================] - 65s 492ms/step - loss: 0.6931 - accuracy: 0.5295 - val_loss: 0.6909 - val_accuracy: 0.5131
# Epoch 4/20
# 133/133 [==============================] - 67s 504ms/step - loss: 0.6941 - accuracy: 0.5239 - val_loss: 0.6930 - val_accuracy: 0.5677
# Epoch 5/20
# 133/133 [==============================] - 66s 494ms/step - loss: 0.6932 - accuracy: 0.5108 - val_loss: 0.6919 - val_accuracy: 0.5495
# Epoch 6/20
# 133/133 [==============================] - 66s 493ms/step - loss: 0.6916 - accuracy: 0.5174 - val_loss: 0.6917 - val_accuracy: 0.5131
# Epoch 7/20
# 133/133 [==============================] - 66s 495ms/step - loss: 0.6920 - accuracy: 0.5098 - val_loss: 0.6955 - val_accuracy: 0.5475
# Epoch 8/20
# 133/133 [==============================] - 66s 495ms/step - loss: 0.6959 - accuracy: 0.5134 - val_loss: 0.6922 - val_accuracy: 0.5131
# Epoch 9/20
# 133/133 [==============================] - 67s 504ms/step - loss: 0.6923 - accuracy: 0.5144 - val_loss: 0.6909 - val_accuracy: 0.5111
# Epoch 10/20
# 133/133 [==============================] - 66s 499ms/step - loss: 0.6939 - accuracy: 0.5254 - val_loss: 0.6896 - val_accuracy: 0.5131
# Epoch 11/20
# 133/133 [==============================] - 66s 494ms/step - loss: 0.6897 - accuracy: 0.5209 - val_loss: 0.6907 - val_accuracy: 0.5253
# Epoch 12/20
# 133/133 [==============================] - 68s 507ms/step - loss: 0.6897 - accuracy: 0.5315 - val_loss: 0.6857 - val_accuracy: 0.5515
# Epoch 13/20
# 133/133 [==============================] - 66s 496ms/step - loss: 0.6826 - accuracy: 0.5607 - val_loss: 0.6902 - val_accuracy: 0.5394
# Epoch 14/20
# 133/133 [==============================] - 66s 497ms/step - loss: 0.6820 - accuracy: 0.5597 - val_loss: 0.6722 - val_accuracy: 0.5535
# Epoch 15/20
# 133/133 [==============================] - 67s 504ms/step - loss: 0.6819 - accuracy: 0.5552 - val_loss: 0.6759 - val_accuracy: 0.5677
# Epoch 16/20
# 133/133 [==============================] - 67s 500ms/step - loss: 0.6791 - accuracy: 0.5632 - val_loss: 0.7623 - val_accuracy: 0.5758
# Epoch 17/20
# 133/133 [==============================] - 67s 505ms/step - loss: 0.6876 - accuracy: 0.5380 - val_loss: 0.6748 - val_accuracy: 0.5374
# Epoch 18/20
# 133/133 [==============================] - 66s 498ms/step - loss: 0.6871 - accuracy: 0.5476 - val_loss: 0.6808 - val_accuracy: 0.5192
# Epoch 19/20
# 133/133 [==============================] - 66s 497ms/step - loss: 0.6830 - accuracy: 0.5582 - val_loss: 0.6778 - val_accuracy: 0.5939
# Epoch 20/20
# 133/133 [==============================] - 67s 506ms/step - loss: 0.6825 - accuracy: 0.5547 - val_loss: 0.6711 - val_accuracy: 0.5859

# %%
show_results(log)

# %%
loss, accuracy = model.evaluate_generator(validation_generator, total_validate//batch_size, workers=12)
print("Test: accuracy = %f  ;  loss = %f " % (accuracy, loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Test: accuracy = 0.587879  ;  loss = 0.670183

# %% [markdown]
# # Probando modelo

# %%
def get_class(path, random_image_path, labels_dict, final_model):
  #Cargar la imagen del path
  img = Image.open(path + "/" + random_image_path).convert("RGB")
  
  #Mostrar la imagen
  plt.imshow(img)
  plt.axis('off')
  
  #Cambiar el tamaño de la imagen
  img_resized = img.resize(IMAGE_SIZE)

  #Cambiar a formato numpy
  x = np.asarray(img_resized, np.float32)
  x = x[None] #(224, 224, 3) -> (1, 224, 224, 3)
  
  #Obtener la predicción
  y = final_model.predict(x)
  
  #Decodificar la predicción
  pred = "cat" if y[0][0] < 0.5 else "dog"
  
  real = random_image_path.split(".", 1)[0]
  
  plt.title(f"Real value = {real} - Model prediction = {pred}")
  plt.show()

# %%
# Visualizando prediciones en validate
labels_dict = {k: i for i, k in validation_generator.class_indices.items()}
number_of_images_to_test = 10

for _ in range(number_of_images_to_test):
  random_image_path = choice(validation_generator.filenames)
  
  get_class(path_train, random_image_path, labels_dict, model)

# %% [markdown]
# # Aplicando modelo

# %%
# Almacenando nombres test de archivos en test_df
test_filenames = os.listdir("test1")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
# Leyendo imagenes en test_generator
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "test1", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    batch_size=batch_size,
    target_size=IMAGE_SIZE,
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %%
# Prediciendo las imagenes de test
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
threshold = 0.5
test_df['category'] = np.where(predict > threshold, 1,0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.

# %%
# Mostrando ejemplos de las prediciones
sample_test = test_df.sample(n=9).reset_index()
sample_test.head()
plt.figure(figsize=(12, 12))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    pred = "cat" if category < 0.5 else "dog"
    img = load_img("test1/"+filename, target_size=(256, 256))
    plt.subplot(3, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(pred) + ')')
plt.tight_layout()
plt.show()
